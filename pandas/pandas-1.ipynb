# %%
import numpy as np
import pandas as pd

# %%
dict1 = { 
    "name" : [ 'harry' , 'rohan' , 'vasu' , 'shubh' ],
    "marks" : [42,50,45,30],
    "city" : ['rampur','kolkata','bareilly','kolhapur']
}

# %%
df = pd.DataFrame(dict1)       #for creating dataframe

# %%
df    #for print complete dataframe
# Out:
#     name  marks      city
# 0  harry     42    rampur
# 1  rohan     50   kolkata
# 2   vasu     45  bareilly
# 3  shubh     30  kolhapur

# %%
df.to_csv('friend.csv')    #for convertind dataframe to csv and storing it locally

# %%
df.to_csv('friend_index_false.csv', index = False)    #for convertind dataframe to csv and storing it locally without index number

# %%
df.head(2)    #for printing top/ head n rows
# Out:
#     name  marks     city
# 0  harry     42   rampur
# 1  rohan     50  kolkata

# %%
df.tail(2)     #for printing bottom  n rows
# Out:
#     name  marks      city
# 2   vasu     45  bareilly
# 3  shubh     30  kolhapur

# %%
df.describe()     #for describing dataframes no of rows,
# Out:
#        marks
# count   4.00
# mean   41.75
# std     8.50
# min    30.00
# 25%    39.00
# 50%    43.50
# 75%    46.25
# max    50.00

# %%
read = pd.read_csv('upload.csv')    #for reading csv file

# %%
read
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0   name  age   class  \
# 0             0             0             0           0  krish   21  B.Tech
# 1             1             1             1           1  naman   22  B.Tech
#
#    marks
# 0     40
# 1     80

# %%
read['marks'][0]     #the way to print perticular cell
# Out:
# 40

# %%
read['marks']       #for reading or printing perticular coloumn
# Out:
# 0    40
# 1    80
# Name: marks, dtype: int64

# %%
read['marks'][0] = 40      #for replacing perticular cell value
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15744\1144695938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   read['marks'][0] = 40      #for replacing perticular cell value

# %%
read
# Out:
#    Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0   name  age   class  \
# 0             0             0             0           0  krish   21  B.Tech
# 1             1             1             1           1  naman   22  B.Tech
#
#    marks
# 0     40
# 1     80

# %%
read.to_csv('upload.csv')

# %%
read.index = ['first','second']    #for renaming index

# %%
read
# Out:
#         Unnamed: 0.3  Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0   name  age  \
# first              0             0             0           0  krish   21
# second             1             1             1           1  naman   22
#
#          class  marks
# first   B.Tech     40
# second  B.Tech     80

# %%
ser = pd.Series(np.random.rand(32))      #

# %%
ser
# Out:
# 0     0.729492
# 1     0.710601
# 2     0.966063
# 3     0.505277
# 4     0.939589
# 5     0.450030
# 6     0.855365
# 7     0.574467
# 8     0.121594
# 9     0.945029
# 10    0.443774
# 11    0.476444
# 12    0.317896
# 13    0.276639
# 14    0.611248
# 15    0.106532
# 16    0.111203
# 17    0.286920
# 18    0.113681
# 19    0.383125
# 20    0.907835
# 21    0.585757
# 22    0.966936
# 23    0.380260
# 24    0.620166
# 25    0.504269
# 26    0.144894
# 27    0.372156
# 28    0.505413
# 29    0.812972
# 30    0.364155
# 31    0.912404
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,6), index = np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4         5
# 0    0
columns]

# %%
newdf.sort_index(axis=1, ascending=False)
# Out:
#             5         4         3         2         1         0
# 0    0.932311  0.510483  0.573862  0.085792  0.432098       0.3
# 1    0.784837  0.987423  0.472912  0.554845  0.694000  0.053119
# 2    0.480493  0.494258  0.973491  0.253967  0.068232  0.678729
# 3    0.871502  0.799183  0.214949  0.822077  0.186670  0.073832
# 4    0.541822  0.318231  0.899349  0.027690  0.901521  0.212248
# ..        ...       ...       ...       ...       ...       ...
# 329  0.703086  0.819692  0.029087  0.580075  0.266281  0.440193
# 330  0.398533  0.151373  0.468398  0.228799  0.254305  0.974817
# 331  0.835009  0.651106  0.278276  0.645956  0.353671  0.635854
# 332  0.274713  0.127958  0.576548  0.681230  0.065109  0.170926
# 333  0.423612  0.624178  0.158915  0.082850  0.075684  0.769707
#
# [334 rows x 6 columns]

# %%
newdf[0]
# Out:
# 0           0.3
# 1      0.053119
# 2      0.678729
# 3      0.073832
# 4      0.212248
#          ...
# 329    0.440193
# 330    0.974817
# 331    0.635854
# 332    0.170926
# 333    0.769707
# Name: 0, Length: 334, dtype: object

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %%
newdf.head()
# Out:
#           0         1         2         3         4         5
# 0       0.3  0.432098  0.085792  0.573862  0.510483  0.932311
# 1  0.053119  0.694000  0.554845  0.472912  0.987423  0.784837
# 2  0.678729  0.068232  0.253967  0.973491  0.494258  0.480493
# 3  0.073832  0.186670  0.822077  0.214949  0.799183  0.871502
# 4  0.212248  0.901521  0.027690  0.899349  0.318231  0.541822

# %%
newdf2 = newdf.copy()

# %%
newdf[1][1] = 0.1
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15744\2820216481.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf[1][1] = 0.1

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4         5
# 0       0.3  0.432098  0.085792  0.573862  0.510483  0.932311
# 1  0.053119  0.100000  0.554845  0.472912  0.987423  0.784837

# %%
newdf2.head(2)
# Out:
#           0         1         2         3         4         5
# 0       0.3  0.432098  0.085792  0.573862  0.510483  0.932311
# 1  0.053119  0.694000  0.554845  0.472912  0.987423  0.784837

# %%
newdf2[1][0] = 0.6
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15744\1690097696.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2[1][0] = 0.6

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4         5
# 0       0.3  0.432098  0.085792  0.573862  0.510483  0.932311
# 1  0.053119  0.100000  0.554845  0.472912  0.987423  0.784837

# %%
newdf2.head(2)
# Out:
#           0      1         2         3         4         5
# 0       0.3  0.600  0.085792  0.573862  0.510483  0.932311
# 1  0.053119  0.694  0.554845  0.472912  0.987423  0.784837

# %%
newdf3 = newdf

# %%
newdf[2][0] = 0.5
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15744\556902890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf[2][0] = 0.5

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4         5
# 0       0.3  0.432098  0.500000  0.573862  0.510483  0.932311
# 1  0.053119  0.100000  0.554845  0.472912  0.987423  0.784837

# %%
newdf3.head(2)
# Out:
#           0         1         2         3         4         5
# 0       0.3  0.432098  0.500000  0.573862  0.510483  0.932311
# 1  0.053119  0.100000  0.554845  0.472912  0.987423  0.784837

# %%
newdf3[2][1] =0.15
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_15744\1648373761.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf3[2][1] =0.15

# %%
newdf3.head(2)
# Out:
#           0         1     2         3         4         5
# 0       0.3  0.432098  0.50  0.573862  0.510483  0.932311
# 1  0.053119  0.100000  0.15  0.472912  0.987423  0.784837

# %%
newdf.head(2)
# Out:
#           0         1     2         3         4         5
# 0       0.3  0.432098  0.50  0.573862  0.510483  0.932311
# 1  0.053119  0.100000  0.15  0.472912  0.987423  0.784837

# %%
newdf.loc[0,0] = 653

# %%
newdf.head(2)
# Out:
#           0         1     2         3         4         5
# 0       653  0.432098  0.50  0.573862  0.510483  0.932311
# 1  0.053119  0.100000  0.15  0.472912  0.987423  0.784837

# %%
newdf.columns = list('ABCDEF')

# %%
newdf.head(2)
# Out:
#           A         B     C         D         E         F
# 0       653  0.432098  0.50  0.573862  0.510483  0.932311
# 1  0.053119  0.100000  0.15  0.472912  0.987423  0.784837

# %%
newdf.loc[0,0] = 65455

# %%
newdf.head()
# Out:
#           A         B         C         D         E         F        0
# 0       653  0.432098  0.500000  0.573862  0.510483  0.932311  65455.0
# 1  0.053119  0.100000  0.150000  0.472912  0.987423  0.784837      NaN
# 2  0.678729  0.068232  0.253967  0.973491  0.494258  0.480493      NaN
# 3  0.073832  0.186670  0.822077  0.214949  0.799183  0.871502      NaN
# 4  0.212248  0.901521  0.027690  0.899349  0.318231  0.541822      NaN

# %%
newdf = newdf.drop('A', axis=1)
newdf = newdf.drop(1)

# %%
newdf.head(2)
# Out:
#           B         C         D         E         F        0
# 0  0.432098  0.500000  0.573862  0.510483  0.932311  65455.0
# 2  0.068232  0.253967  0.973491  0.494258  0.480493      NaN

# %%
newdf.loc[[2,3],['C','D']]      #newdf.loc[:,['C','D']]  all row   newdf.loc[[2,3],['C','D']]    all column
# Out:
#           C         D
# 2  0.253967  0.973491
# 3  0.822077  0.214949

# %%
newdf.loc[(newdf['B']<0.3)]
# Out:
#             B         C         D         E         F   0
# 2    0.068232  0.253967  0.973491  0.494258  0.480493 NaN
# 3    0.186670  0.822077  0.214949  0.799183  0.871502 NaN
# 5    0.255178  0.643989  0.136694  0.665762  0.615964 NaN
# 6    0.137306  0.562469  0.723998  0.157271  0.408376 NaN
# 15   0.169349  0.096753  0.991228  0.035430  0.084472 NaN
# ..        ...       ...       ...       ...       ...  ..
# 324  0.071043  0.183189  0.828213  0.926423  0.230515 NaN
# 329  0.266281  0.580075  0.029087  0.819692  0.703086 NaN
# 330  0.254305  0.228799  0.468398  0.151373  0.398533 NaN
# 332  0.065109  0.681230  0.576548  0.127958  0.274713 NaN
# 333  0.075684  0.082850  0.158915  0.624178  0.423612 NaN
#
# [102 rows x 6 columns]

# %%
newdf.loc[(newdf['B']<0.3) & (newdf['C']>0.1)]
# Out:
#             B         C         D         E         F   0
# 2    0.068232  0.253967  0.973491  0.494258  0.480493 NaN
# 3    0.186670  0.822077  0.214949  0.799183  0.871502 NaN
# 5    0.255178  0.643989  0.136694  0.665762  0.615964 NaN
# 6    0.137306  0.562469  0.723998  0.157271  0.408376 NaN
# 19   0.277922  0.963088  0.546921  0.997224  0.001054 NaN
# ..        ...       ...       ...       ...       ...  ..
# 322  0.296798  0.995363  0.615385  0.208819  0.660948 NaN
# 324  0.071043  0.183189  0.828213  0.926423  0.230515 NaN
# 329  0.266281  0.580075  0.029087  0.819692  0.703086 NaN
# 330  0.254305  0.228799  0.468398  0.151373  0.398533 NaN
# 332  0.065109  0.681230  0.576548  0.127958  0.274713 NaN
#
# [91 rows x 6 columns]

# %%
newdf.head(2)
# Out:
#           B         C         D         E         F        0
# 0  0.432098  0.500000  0.573862  0.510483  0.932311  65455.0
# 2  0.068232  0.253967  0.973491  0.494258  0.480493      NaN

# %%
newdf.iloc[0,4]
# Out:
# 0.9323108487080644

# %%
newdf.iloc[[0,5],[1,2]]
# Out:
#           C         D
# 0  0.500000  0.573862
# 6  0.562469  0.723998

# %%
newdf.head(3)
# Out:
#           B         C         D         E         F        0
# 0  0.432098  0.500000  0.573862  0.510483  0.932311  65455.0
# 2  0.068232  0.253967  0.973491  0.494258  0.480493      NaN
# 3  0.186670  0.822077  0.214949  0.799183  0.871502      NaN

# %%
newdf.drop([0],axis=1)
# Out:
#             B         C         D         E         F
# 0    0.432098  0.500000  0.573862  0.510483  0.932311
# 2    0.068232  0.253967  0.973491  0.494258  0.480493
# 3    0.186670  0.822077  0.214949  0.799183  0.871502
# 4    0.901521  0.027690  0.899349  0.318231  0.541822
# 5    0.255178  0.643989  0.136694  0.665762  0.615964
# ..        ...       ...       ...       ...       ...
# 329  0.266281  0.580075  0.029087  0.819692  0.703086
# 330  0.254305  0.228799  0.468398  0.151373  0.398533
# 331  0.353671  0.645956  0.278276  0.651106  0.835009
# 332  0.065109  0.681230  0.576548  0.127958  0.274713
# 333  0.075684  0.082850  0.158915  0.624178  0.423612
#
# [333 rows x 5 columns]

# %%
newdf
# Out:
#             B         C         D         E         F        0
# 0    0.432098  0.500000  0.573862  0.510483  0.932311  65455.0
# 2    0.068232  0.253967  0.973491  0.494258  0.480493      NaN
# 3    0.186670  0.822077  0.214949  0.799183  0.871502      NaN
# 4    0.901521  0.027690  0.899349  0.318231  0.541822      NaN
# 5    0.255178  0.643989  0.136694  0.665762  0.615964      NaN
# ..        ...       ...       ...       ...       ...      ...
# 329  0.266281  0.580075  0.029087  0.819692  0.703086      NaN
# 330  0.254305  0.228799  0.468398  0.151373  0.398533      NaN
# 331  0.353671  0.645956  0.278276  0.651106  0.835009      NaN
# 332  0.065109  0.681230  0.576548  0.127958  0.274713      NaN
# 333  0.075684  0.082850  0.158915  0.624178  0.423612      NaN
#
# [333 rows x 6 columns]

# %%
newdf.drop([0],axis=1 , inplace=True)

# %%
newdf
# Out:
#             B         C         D         E         F
# 0    0.432098  0.500000  0.573862  0.510483  0.932311
# 2    0.068232  0.253967  0.973491  0.494258  0.480493
# 3    0.186670  0.822077  0.214949  0.799183  0.871502
# 4    0.901521  0.027690  0.899349  0.318231  0.541822
# 5    0.255178  0.643989  0.136694  0.665762  0.615964
# ..        ...       ...       ...       ...       ...
# 329  0.266281  0.580075  0.029087  0.819692  0.703086
# 330  0.254305  0.228799  0.468398  0.151373  0.398533
# 331  0.353671  0.645956  0.278276  0.651106  0.835009
# 332  0.065109  0.681230  0.576548  0.127958  0.274713
# 333  0.075684  0.082850  0.158915  0.624178  0.423612
#
# [333 rows x 5 columns]

# %%
newdf.reset_index()
# Out:
#      index         B         C         D         E         F
# 0        0  0.432098  0.500000  0.573862  0.510483  0.932311
# 1        2  0.068232  0.253967  0.973491  0.494258  0.480493
# 2        3  0.186670  0.822077  0.214949  0.799183  0.871502
# 3        4  0.901521  0.027690  0.899349  0.318231  0.541822
# 4        5  0.255178  0.643989  0.136694  0.665762  0.615964
# ..     ...       ...       ...       ...       ...       ...
# 328    329  0.266281  0.580075  0.029087  0.819692  0.703086
# 329    330  0.254305  0.228799  0.468398  0.151373  0.398533
# 330    331  0.353671  0.645956  0.278276  0.651106  0.835009
# 331    332  0.065109  0.681230  0.576548  0.127958  0.274713
# 332    333  0.075684  0.082850  0.158915  0.624178  0.423612
#
# [333 rows x 6 columns]

# %%
newdf.reset_index(drop=True,inplace=True)

# %%
newdf.head(3)
# Out:
#           B         C         D         E         F
# 0  0.432098  0.500000  0.573862  0.510483  0.932311
# 1  0.068232  0.253967  0.973491  0.494258  0.480493
# 2  0.186670  0.822077  0.214949  0.799183  0.871502

# %%
newdf['B'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 328    False
# 329    False
# 330    False
# 331    False
# 332    False
# Name: B, Length: 333, dtype: bool

# %%
newdf['B']= None

# %%
newdf
# Out:
#         B         C         D         E         F
# 0    None  0.500000  0.573862  0.510483  0.932311
# 1    None  0.253967  0.973491  0.494258  0.480493
# 2    None  0.822077  0.214949  0.799183  0.871502
# 3    None  0.027690  0.899349  0.318231  0.541822
# 4    None  0.643989  0.136694  0.665762  0.615964
# ..    ...       ...       ...       ...       ...
# 328  None  0.580075  0.029087  0.819692  0.703086
# 329  None  0.228799  0.468398  0.151373  0.398533
# 330  None  0.645956  0.278276  0.651106  0.835009
# 331  None  0.681230  0.576548  0.127958  0.274713
# 332  None  0.082850  0.158915  0.624178  0.423612
#
# [333 rows x 5 columns]

# %%
newdf.loc[:,['B']]=90

# %%
newdf
# Out:
#       B         C         D         E         F
# 0    90  0.500000  0.573862  0.510483  0.932311
# 1    90  0.253967  0.973491  0.494258  0.480493
# 2    90  0.822077  0.214949  0.799183  0.871502
# 3    90  0.027690  0.899349  0.318231  0.541822
# 4    90  0.643989  0.136694  0.665762  0.615964
# ..   ..       ...       ...       ...       ...
# 328  90  0.580075  0.029087  0.819692  0.703086
# 329  90  0.228799  0.468398  0.151373  0.398533
# 330  90  0.645956  0.278276  0.651106  0.835009
# 331  90  0.681230  0.576548  0.127958  0.274713
# 332  90  0.082850  0.158915  0.624178  0.423612
#
# [333 rows x 5 columns]

# %%
df=pd.DataFrame({"name":['Batann','Batann','Catwomen'],
                "toy":[np.nan,'batmobile','Fullship'],
                "born":[pd.NaT,pd.Timestamp("1990-04-05"),pd.NaT]
               })

# %%
df
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batann  batmobile 1990-04-05
# 2  Catwomen   Fullship        NaT

# %%
df.dropna(how='all',axis=1)
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batann  batmobile 1990-04-05
# 2  Catwomen   Fullship        NaT

# %%
df.head()
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batann  batmobile 1990-04-05
# 2  Catwomen   Fullship        NaT

# %%
df.drop_duplicates(subset=['name'],keep='first')
# Out:
#        name        toy       born
# 0    Alfred        NaN        NaT
# 1    Batann  batmobile 1990-04-05
# 2  Catwomen   Fullship        NaT

# %%
df.drop_duplicates(subset=['name'],keep='last')
# Out:
#        name        toy       born
# 1    Batann  batmobile 1990-04-05
# 2  Catwomen   Fullship        NaT

# %%
df.drop_duplicates(subset=['name'],keep=False)
# Out:
#        name       toy born
# 2  Catwomen  Fullship  NaT

# %%
df.shape
# Out:
# (3, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   toy     2 non-null      object
#  2   born    1 non-null      datetime64[ns]
# dtypes: datetime64[ns](1), object(2)
# memory usage: 204.0+ bytes

# %%
df['toy'].value_counts(dropna=False)
# Out:
# toy
# NaN          1
# batmobile    1
# Fullship     1
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#     name    toy   born
# 0  False   True   True
# 1  False  False  False
# 2  False  False   True
